# %%
import chromadb
import pandas as pd
import polars as pl

# %%
client = chromadb.Client()

# %%
collection = client.get_or_create_collection(name="employees")

# %%
data = pl.read_csv('employee.csv').with_row_index(offset=1)

# %%
data.head(5)
# Out:
# shape: (5, 6)
# ┌───────┬────────────┬───────────────┬────────────┬─────────────┬──────────────────────────┐
# │ index ┆    id      ┆ name          ┆ experience ┆ department  ┆ role                     │
# │ ---   ┆ ---        ┆ ---           ┆ ---        ┆ ---         ┆ ---                      │
# │ u32   ┆ str        ┆ str           ┆ i64        ┆ str         ┆ str                      │
# ╞═══════╪════════════╪═══════════════╪════════════╪═════════════╪══════════════════════════╡
# │ 1     ┆ employee_1 ┆ John Doe      ┆ 5          ┆ Engineering ┆ Software Engineer        │
# │ 2     ┆ employee_2 ┆ Jane Smith    ┆ 8          ┆ Marketing   ┆ Marketing Manager        │
# │ 3     ┆ employee_3 ┆ Alice Johnson ┆ 3          ┆ HR          ┆ HR Coordinator           │
# │ 4     ┆ employee_4 ┆ Michael Brown ┆ 12         ┆ Engineering ┆ Senior Software Engineer │
# │ 5     ┆ employee_5 ┆ Emily Wilson  ┆ 2          ┆ Marketing   ┆ Marketing Assistant      │
# └───────┴────────────┴───────────────┴────────────┴─────────────┴──────────────────────────┘
